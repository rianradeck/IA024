# %% [markdown]
# # Notebook Processo Seletivo Aluno Especial IA-024 1S2024 FEEC-UNICAMP
# versão 5 de fevereiro de 2024, 19h
# versão 8 de fevereiro de 2024, 20h - ajuste variável vocab_size

# %%
# This notebook was based on the given notebook by professor Roberto.
# It suffered many alteration throughout the development of the project.
# This is it's final form, please read the report about it's development
# to see all the history.

# Author: Rian Radeck
# Academic Register (RA): 187793

# Please uncomment these lines to install dependencies.
# !pip install torchtext
# !pip install 'portalocker>=2.0.0'
# !pip install matplotlib
# !pip install unidecode
# !pip install nltk

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchtext.datasets import IMDB
from collections import Counter
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %% [markdown]
# ## I - Vocabulário e Tokenização

# %%
# This cell is responsible to process strings for the tokenizer.

# Treating strings, generated by GPT 3.5-turbo

import string
import unicodedata
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

def remove_accents(input_str):
    # Remove accents from characters
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return "".join([c for c in nfkd_form if not unicodedata.combining(c)])

def remove_punctuation(input_str):
    # Remove punctuation using string.punctuation
    translator = str.maketrans('', '', string.punctuation)
    return input_str.translate(translator)

def remove_stopwords(input_str, remove_stopwords_flag=False):
    # Remove English stopwords using NLTK
    if remove_stopwords_flag:
        english_stopwords = set(stopwords.words('english'))
        words = input_str.split()
        filtered_words = [word for word in words if word.lower() not in english_stopwords]
        return ' '.join(filtered_words)
    else:
        return input_str

def preprocess_text(text, remove_stopwords_flag=False):
    # Combine all preprocessing steps
    text = remove_accents(text)
    text = remove_punctuation(text)
    text = remove_stopwords(text, remove_stopwords_flag)
    return text.lower()

# Example usage:
input_text = "Héllo, thïs is a tést! It includes accents and punctuation. Also, it has English stopwords."
preprocessed_text = preprocess_text(input_text, remove_stopwords_flag=True)
print("Preprocessed text:", preprocessed_text)
# Out:
# Preprocessed text: hello test includes accents punctuation also english stopwords
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rianr\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# This cell is responsible for the generation of the vocabulary
# that will be used throughout the notebook.
# Here you will find the main parameters of the vocabulary construction.
# Please pay attention to the reduce_dataset flag and the vocab_size variable.

# limit the vocabulary size to 20000 most frequent tokens
vocab_size = 20000

# Initialize a Counter object to count occurrences of individual words
counter = Counter()

# Initialize a Counter object to count occurrences of labels (e.g., positive/negative sentiment)
label_counter = Counter()

# Initialize a variable to keep track of the total number of words in the dataset
total_words = 0

# Reduce dataset if needed
reduce_dataset = False

# This will be the number of train and test samples used.
reduced_dataset_size = 1000

dataset_train = list(IMDB(split='train')).copy()
for i in range(len(dataset_train)):
    dataset_train[i] = dataset_train[i][0], preprocess_text(dataset_train[i][1], False)
if reduce_dataset:
    np.random.shuffle(dataset_train)
    dataset_train = dataset_train[:reduced_dataset_size]

# Iterate over each review in the training set obtained from the IMDB dataset
for (label, line) in dataset_train:
    # Split the review text into individual words
    words_in_line = line.split()

    # Update the total number of words by adding the number of words in the current review
    total_words += len(words_in_line)

    # Update the Counter object with the individual words in the current review
    counter.update(words_in_line)

    # Update the Counter object with the label of the current review
    label_counter.update([label])

# Count the total number of reviews in the training set
number_of_reviews = len(dataset_train)

# Calculate the average number of words per review
avg_words_in_review = total_words / number_of_reviews

# create a vocabulary of the 20000 most frequent tokens
most_frequent_words = sorted(counter, key=counter.get, reverse=True)[:vocab_size]
vocab = {word: i for i, word in enumerate(most_frequent_words, 1)} # words indexed from 1 to 20000
vocab_size = len(vocab)
print(f"Negative labels: {label_counter.get(1)}\nPositive labels: {label_counter.get(2)}\nTotal labels: {number_of_reviews}")
print("Average number of words in a review", avg_words_in_review)
# Out:
# Negative labels: 12500
# Positive labels: 12500
# Total labels: 25000
# Average number of words in a review 232.88088

# %%
# Definition of the encoder, using a given vocabulary.

def encode_sentence(sentence, vocab):
    return [vocab.get(word, 0) for word in sentence.split()] # 0 for OOV

encode_sentence("i like pizza", vocab)
# Out:
# [9, 38, 7929]

# %%
# Code to calculate 5 most frequent words, 5 least frequent words 
# and number of words in dataset without encoding.
# Note that we are calculating the total number of words, and not
# the number of unique words/tokens.

print("5 most frequent words:", most_frequent_words[:5])
print("5 least frequent words:", most_frequent_words[-5:])
number_of_tokened_words = np.sum([(freq if encode_sentence(word, vocab) != [0] else 0) for (word, freq) in counter.items()])
print("Number of words with a token:", number_of_tokened_words)
print("Number of words without a token:", total_words - number_of_tokened_words)
# Out:
# 5 most frequent words: ['the', 'and', 'a', 'of', 'to']
# 5 least frequent words: ['whistler', 'ponderosa', 'dolores', 'showings', 'cacoyannis']
# Number of words with a token: 5608268
# Number of words without a token: 213754

# %% [markdown]
# ## II - Dataset

# %%
# This cell defines the dataloader class.

# Dataset Class with One-hot Encoding
class IMDBDataset(Dataset):
    def __init__(self, split, vocab):

        self.data = list(IMDB(split=split))  # Loading IMDB data for specified split
        if reduce_dataset:  # Check if dataset reduction is enabled
          np.random.shuffle(self.data)  # Shuffle the data
          self.data = self.data[:reduced_dataset_size]  # Reduce dataset size if specified
        self.vocab = vocab  # Set vocabulary

    def __len__(self):
        return len(self.data)  # Return the length of the dataset

    def __getitem__(self, idx):
        label, line = self.data[idx]  # Get label and text for specified index
        label = 1 if label == 1 else 0  # Convert label to binary (1 for positive, 0 for negative)

        # one-hot encoding
        X = torch.zeros(len(self.vocab) + 1)  # Initialize one-hot encoded tensor
        for word in encode_sentence(line, self.vocab):  # Iterate over words in the encoded sentence
            X[word] = 1  # Set corresponding index to 1 for one-hot encoding

        return X, torch.tensor(label)  # Return one-hot encoded tensor and label


# Load Data with One-hot Encoding
train_data = IMDBDataset('train', vocab)  # Load training data
test_data = IMDBDataset('test', vocab)  # Load testing data

# Counting the number of positive and negative labels
# Calculating number of ON neurons
label_counter = Counter()  # Initialize counter for label occurrences
idx = 0  # Initialize index counter
total_on_words = 0  # Initialize counter for total "ON" neurons
for label, line in train_data.data:  # Iterate over training data
    label_counter.update([label])  # Update label counter

    total_on_words += np.count_nonzero(train_data[idx][0] == 1)  # Count "ON" neurons in current sample
    idx += 1  # Increment index counter
average_on_words_by_review = total_on_words / len(train_data)  # Calculate average "ON" neurons per review
print(f"Negative labels: {label_counter.get(1)}")  # Print number of negative labels
print(f"Positive labels: {label_counter.get(2)}")  # Print number of positive labels
print(f"Average ON neurons: {average_on_words_by_review}")  # Print average "ON" neurons per review
# Out:
# Negative labels: 12500
# Positive labels: 12500
# Average ON neurons: 101.88064

# %% [markdown]
# ## III - Data Loader

# %%
# This cell defines the batch size and initializes the train and test loaders.

# Define batch size for training
batch_size = 128

# Define dataloaders
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %%
# This code is used to verify some properties of the dataset:
#     - Number of batches
#     - Number of samples in the last batch
#     - Shape of batches and samples.

# Initialize counters for tracking properties of the dataset.
batches_cnt = 0  # Counter for the number of batches processed.
last_batch = None  # Placeholder for the last batch processed.

# Loop through each batch in the train_loader.
for batch in train_loader:
    batches_cnt += 1  # Increment the batch counter.
    last_batch = batch  # Update the last_batch with the current batch.

# Print the total number of batches processed.
print("Total number of batches:", batches_cnt)

# Print the number of samples in the last batch.
print("Number of samples in the last batch:", len(last_batch[1]))

# Retrieve the first batch using next and iter, then print the first sample's data and label.
first_batch = next(iter(train_loader))
print("First sample's data:", first_batch[0][0])
print("First sample's label:", first_batch[1][0])

# Calculate and print the average number of non-zero elements in the labels across all batches.
print("Average R:", np.average([np.count_nonzero(label == 1) for _, label in train_loader]) / batch_size)
# Out:
# Total number of batches: 196
# Number of samples in the last batch: 40
# First sample's data: tensor([1., 1., 1.,  ..., 0., 0., 0.])
# First sample's label: tensor(0)
# Average R: 0.49824617346938777

# %% [markdown]
# ## IV - Modelo

# %%
# This cell defines the neural network.

class OneHotMLP(nn.Module):
    def __init__(self, vocab_size):
        super(OneHotMLP, self).__init__()

        # Define the first fully connected layer with input size of (vocab_size + 1) and output size of 200.
        self.fc1 = nn.Linear(vocab_size + 1, 200)

        # Define the second fully connected layer with input size of 200 and output size of 2.
        self.fc2 = nn.Linear(200, 2)

        # Define the activation function ReLU.
        self.relu = nn.ReLU()

    def forward(self, x):
        # Pass the input x through the first fully connected layer and apply ReLU activation.
        o = self.fc1(x.float())
        o = self.relu(o)
        
        # Pass the output of the first layer through the second fully connected layer.
        return self.fc2(o)

# %%
# This is legacy code, used in the one logit model.

# # model = OneHotMLP(vocab_size)
# model = train(0.1)

# model = model.to('cpu')
# input, label = first_batch
# logit = model(input)
# logit = torch.sigmoid(logit)

# corrects = 0
# predicted = torch.round(logit)
# for i in range(batch_size):
#     corrects += int(predicted[i]) == int(label[i])
# print(f"Acurácia: {100 * corrects / batch_size}")
# print(f"Input shape {input.shape}\nLabel shape {label.shape}")

# %% [markdown]
# ## V - Laço de Treinamento - Otimização da função de Perda pelo Gradiente descendente

# %%
# Verifies what devices are available and uses GPU if possible.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if device.type == 'cuda':
    print('GPU:', torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print('using CPU')
# Out:
# GPU: NVIDIA GeForce RTX 3060 Ti

# %%
# This cell defines the cross entropy function and the binary cross entropy function.

def exp_loss(target, prob):
    # Check if the lengths of target and prob are equal.
    assert len(target) == len(prob), "Target and Prob have different sizes."
    
    # Convert target and prob to numpy arrays and squeeze to remove any singleton dimensions.
    target = np.array(target).squeeze()
    prob = np.array(prob.detach().numpy()).squeeze()
    
    # Get the number of samples.
    N = len(target)
    
    # Compute the loss using the formula.
    return - np.sum(target * np.log(prob) + (1 - target) * np.log(1 - prob)) / N

def NL_loss(target, prob):
    # Check if the lengths of target and prob are equal.
    assert len(target) == len(prob), "Target and Prob have different sizes."
    
    # Convert target and prob to numpy arrays and squeeze to remove any singleton dimensions.
    target = np.array(target).squeeze()
    prob = np.array(prob.detach().numpy()).squeeze()
    
    # Get the number of samples and the number of classes.
    N = len(target)
    C = len(target[0])
    
    # Initialize sum to accumulate the loss.
    sum = 0
    
    # Loop through each sample and each class to compute the loss.
    for i in range(N):
        for c in range(C):
            sum += target[i][c] * np.log(prob[i][c])
    
    # Compute the loss using the formula.
    return - sum / N

# %%
# This is legacy code, used in the one logit model.

# input, label = first_batch
# model = OneHotMLP(vocab_size)
# outputs = model(input)
# probs = torch.sigmoid(outputs)

# bce = nn.BCELoss()
# bce_logits = nn.BCEWithLogitsLoss()

# print(exp_loss(label, probs))
# print(float(bce(probs.squeeze(), label.float())))
# print(float(bce_logits(outputs.squeeze(), label.float())))

# %%
# Extract input data and labels from the first batch.
input, label = first_batch

# Instantiate the OneHotMLP model with the specified vocab_size.
model = OneHotMLP(vocab_size)

# Forward pass through the model to obtain outputs.
outputs = model(input)

# Compute log probabilities using log softmax along dimension 1.
probs = torch.log_softmax(outputs, dim=1)

# Compute probabilities using softmax along dimension 1.
probs_ = torch.softmax(outputs, dim=1)

# Create logits_label tensor with labels transformed into 2 logits format.
logits_label = torch.tensor([(int(not label), int(label)) for label in label])

# Instantiate NLLLoss and CrossEntropyLoss classes.
CE = nn.NLLLoss()
SMCE = nn.CrossEntropyLoss()

# Print the cross-entropy loss defined explicitly by the NL_loss function.
print(NL_loss(logits_label, probs_))

# Print the cross-entropy loss using nn.NLLLoss().
print(float(CE(probs, label)))

# Print the cross-entropy loss using nn.CrossEntropyLoss().
print(float(SMCE(outputs.squeeze(), label)))
# Out:
# 0.6925091627053916
# 0.6925091743469238
# 0.6925091743469238

# %%
# This cell is responsible of taking all training data to device. 

# Taking data to device is taking 28s
# This will reduce each epoch training to 0.6s

# Taking data each epoch is taking 31s per epoch

# Initialize empty lists to store inputs and labels after moving them to the specified device.
on_device_inputs = []
on_device_labels = []

# Iterate over each batch of data in the train_loader.
for inputs, labels in train_loader:
    # Move inputs and labels to the specified device and append them to the respective lists.
    on_device_inputs.append(inputs.to(device))
    on_device_labels.append(labels.to(device))

# Create a new list of tuples containing (input, label) pairs, with each pair residing on the specified device.
on_device_train_loader = [(on_device_inputs[i], on_device_labels[i]) for i in range(len(train_loader))]

# %%
import time

def train(lr, doeval=False, num_epochs=5):
    # Instantiate the OneHotMLP model and move it to the specified device.
    model = OneHotMLP(vocab_size)
    model = model.to(device)
    
    # Define loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr)
    
    # Lists to store performance metrics during training if doeval is True
    performance_test = []
    performance_train = []
    
    # Training loop over epochs
    for epoch in range(num_epochs):
        start_time = time.time()  # Start time of the epoch
        
        # Set the model to training mode
        model.train()
        
        # Loop over batches in the on_device_train_loader
        for inputs, labels in on_device_train_loader:
            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), labels)
            
            # Back propagation and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        end_time = time.time()  # End time of the epoch
        epoch_duration = end_time - start_time  # Duration of epoch

        # Print epoch information including loss and elapsed time
        print(f'Epoch [{epoch+1}/{num_epochs}], \
                Loss: {loss.item():.4f}, \
                Elapsed Time: {epoch_duration:.2f} sec')
        
        # If doeval is True, evaluate the model on both training and test datasets
        if doeval:
            performance_test.append(eval(model, loader='test'))
            performance_train.append(eval(model, loader='train'))

    # Return the trained model if doeval is False, otherwise return the trained model along with performance metrics
    return model if not doeval else (model, performance_test, performance_train)

# %% [markdown]
# ## VI - Avaliação

# %%
# This cell is responsible of taking all test data to device. 

# Initialize empty lists to store inputs and labels after moving them to the specified device.
on_device_inputs = []
on_device_labels = []

# Iterate over each batch of data in the test_loader.
for inputs, labels in test_loader:
    # Move inputs and labels to the specified device and append them to the respective lists.
    on_device_inputs.append(inputs.to(device))
    on_device_labels.append(labels.to(device))

# Create a new list of tuples containing (input, label) pairs, with each pair residing on the specified device.
on_device_test_loader = [(on_device_inputs[i], on_device_labels[i]) for i in range(len(test_loader))]

# %%
# This cell defines the evaluation function.

## Evaluation function
def convert_output(output):
    # Apply softmax and round the output to obtain binary predictions
    output = torch.round(torch.softmax(output, dim=1))
    # Convert binary predictions to tensor of 0s and 1s, then move it to the specified device
    return torch.tensor([0 if int(output[0]) == 1 else 1 for output in output]).to(device)

def eval(model, loader='test'):
    # Set the model to evaluation mode
    model.eval()
    # Define the loss criterion
    criterion = nn.CrossEntropyLoss()
    # Initialize total loss
    total_loss = 0.0
    # Select the appropriate data loader based on the input loader argument
    data_loader = on_device_test_loader if loader == 'test' else on_device_train_loader

    # Disable gradient computation since no gradients are needed during evaluation
    with torch.no_grad():
        # Initialize correct and total counters for accuracy calculation
        correct = 0
        total = 0
        # Iterate over batches in the selected data loader
        for inputs, labels in data_loader:
            # Forward pass to obtain model outputs
            outputs = model(inputs)
            # Convert model outputs to binary predictions using convert_output function
            predicted = convert_output(outputs)
            
            # Calculate loss
            loss = criterion(outputs, labels)
            # Accumulate total loss
            total_loss += loss.item()
            
            # Update total count of labels and count of correctly predicted labels
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Calculate average loss
        avg_loss = total_loss / len(test_loader.dataset) 
        # Calculate perplexity (PPL)
        ppl = np.exp(avg_loss)
        # Calculate accuracy
        acc = 100 * correct / total
        
        # Print evaluation metrics: loss, perplexity, and accuracy
        print(f'{loader} Loss: {avg_loss:.4f}')
        print(f'{loader} PPL: {ppl:.4f}')
        print(f'{loader} Accuracy: {acc}%')
        
        # Return accuracy, perplexity, and average loss
        return acc, ppl, avg_loss

# %% [markdown]
# # Gráficos

# %%
model, performance_test, performance_train = train(0.1, doeval=True, num_epochs=50)
# Out:
# Epoch [1/50],                 Loss: 0.3693,                 Elapsed Time: 0.29 sec
# test Loss: 0.0031
# test PPL: 1.0031
# test Accuracy: 82.816%
# train Loss: 0.0030
# train PPL: 1.0030
# train Accuracy: 84.384%
# Epoch [2/50],                 Loss: 0.2697,                 Elapsed Time: 0.19 sec
# test Loss: 0.0029
# test PPL: 1.0029
# test Accuracy: 83.912%
# train Loss: 0.0026
# train PPL: 1.0026
# train Accuracy: 86.084%
# Epoch [3/50],                 Loss: 0.2189,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.408%
# train Loss: 0.0024
# train PPL: 1.0024
# train Accuracy: 87.388%
# Epoch [4/50],                 Loss: 0.1921,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.548%
# train Loss: 0.0022
# train PPL: 1.0022
# train Accuracy: 88.176%
# Epoch [5/50],                 Loss: 0.1746,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.544%
# train Loss: 0.0021
# train PPL: 1.0021
# train Accuracy: 88.776%
# Epoch [6/50],                 Loss: 0.1763,                 Elapsed Time: 0.20 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.444%
# train Loss: 0.0020
# train PPL: 1.0020
# train Accuracy: 89.168%
# Epoch [7/50],                 Loss: 0.1947,                 Elapsed Time: 0.21 sec
# test Loss: 0.0029
# test PPL: 1.0029
# test Accuracy: 84.032%
# train Loss: 0.0020
# train PPL: 1.0020
# train Accuracy: 89.008%
# Epoch [8/50],                 Loss: 0.1442,                 Elapsed Time: 0.19 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.284%
# train Loss: 0.0017
# train PPL: 1.0017
# train Accuracy: 91.336%
# Epoch [9/50],                 Loss: 0.1594,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.86%
# train Loss: 0.0017
# train PPL: 1.0017
# train Accuracy: 91.144%
# Epoch [10/50],                 Loss: 0.1047,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.864%
# train Loss: 0.0014
# train PPL: 1.0014
# train Accuracy: 93.072%
# Epoch [11/50],                 Loss: 0.1336,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 85.324%
# train Loss: 0.0014
# train PPL: 1.0014
# train Accuracy: 92.832%
# Epoch [12/50],                 Loss: 0.0960,                 Elapsed Time: 0.19 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.912%
# train Loss: 0.0012
# train PPL: 1.0012
# train Accuracy: 94.06%
# Epoch [13/50],                 Loss: 0.0930,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 85.464%
# train Loss: 0.0012
# train PPL: 1.0012
# train Accuracy: 93.964%
# Epoch [14/50],                 Loss: 0.0669,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 85.76%
# train Loss: 0.0011
# train PPL: 1.0011
# train Accuracy: 94.948%
# Epoch [15/50],                 Loss: 0.0602,                 Elapsed Time: 0.19 sec
# test Loss: 0.0029
# test PPL: 1.0029
# test Accuracy: 85.724%
# train Loss: 0.0010
# train PPL: 1.0010
# train Accuracy: 95.476%
# Epoch [16/50],                 Loss: 0.0679,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 85.796%
# train Loss: 0.0009
# train PPL: 1.0009
# train Accuracy: 96.312%
# Epoch [17/50],                 Loss: 0.0854,                 Elapsed Time: 0.18 sec
# test Loss: 0.0030
# test PPL: 1.0030
# test Accuracy: 85.432%
# train Loss: 0.0009
# train PPL: 1.0009
# train Accuracy: 96.352%
# Epoch [18/50],                 Loss: 0.0342,                 Elapsed Time: 0.18 sec
# test Loss: 0.0030
# test PPL: 1.0030
# test Accuracy: 85.752%
# train Loss: 0.0008
# train PPL: 1.0008
# train Accuracy: 97.008%
# Epoch [19/50],                 Loss: 0.0342,                 Elapsed Time: 0.19 sec
# test Loss: 0.0031
# test PPL: 1.0031
# test Accuracy: 85.476%
# train Loss: 0.0007
# train PPL: 1.0007
# train Accuracy: 97.336%
# Epoch [20/50],                 Loss: 0.0273,                 Elapsed Time: 0.20 sec
# test Loss: 0.0032
# test PPL: 1.0032
# test Accuracy: 85.508%
# train Loss: 0.0006
# train PPL: 1.0006
# train Accuracy: 97.736%
# Epoch [21/50],                 Loss: 0.0223,                 Elapsed Time: 0.20 sec
# test Loss: 0.0033
# test PPL: 1.0033
# test Accuracy: 85.572%
# train Loss: 0.0006
# train PPL: 1.0006
# train Accuracy: 98.252%
# Epoch [22/50],                 Loss: 0.0211,                 Elapsed Time: 0.19 sec
# test Loss: 0.0033
# test PPL: 1.0034
# test Accuracy: 85.384%
# train Loss: 0.0005
# train PPL: 1.0005
# train Accuracy: 98.656%
# Epoch [23/50],                 Loss: 0.0187,                 Elapsed Time: 0.19 sec
# test Loss: 0.0033
# test PPL: 1.0033
# test Accuracy: 85.572%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 model, performance_test, performance_train = train(0.1, doeval=True, num_epochs=50)
#
# Cell In [17], line 45, in train(lr, doeval, num_epochs)
#      43     if doeval:
#      44         performance_test.append(eval(model, loader='test'))
# ---> 45         performance_train.append(eval(model, loader='train'))
#      47 # Return the trained model if doeval is False, otherwise return the trained model along with performance metrics
#      48 return model if not doeval else (model, performance_test, performance_train)
#
# Cell In [19], line 30, in eval(model, loader)
#      28 outputs = model(inputs)
#      29 # Convert model outputs to binary predictions using convert_output function
# ---> 30 predicted = convert_output(outputs)
#      32 # Calculate loss
#      33 loss = criterion(outputs, labels)
#
# Cell In [19], line 8, in convert_output(output)
#       6 output = torch.round(torch.softmax(output, dim=1))
#       7 # Convert binary predictions to tensor of 0s and 1s, then move it to the specified device
# ----> 8 return torch.tensor([0 if int(output[0]) == 1 else 1 for output in output]).to(device)
#
# Cell In [19], line 8, in <listcomp>(.0)
#       6 output = torch.round(torch.softmax(output, dim=1))
#       7 # Convert binary predictions to tensor of 0s and 1s, then move it to the specified device
# ----> 8 return torch.tensor([0 if int(output[0]) == 1 else 1 for output in output]).to(device)
#
# KeyboardInterrupt:

# %%
# This cell is responsible to plotting perplexity changes according to number of epochs.

import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

def plot_list_trend(ax, l, label):
    # Create an array representing the index of each data point
    X = np.array([i for i in range(1, len(l) + 1)])
    # Create a spline interpolation function using X and the provided data
    X_Y_Spline = make_interp_spline(X, l)
    # Generate a denser set of X values for smoother plotting
    X_ = np.linspace(X.min(), X.max(), 500)
    # Use the interpolation function to get corresponding Y values
    Y_ = X_Y_Spline(X_)
    # Find the index of the minimum value in the provided data
    min_value_idx = np.argmin(l)
    # Plot the data on the provided axis
    ax.plot(X_, Y_, label=label)
    # Set the label for the x-axis
    ax.set_xlabel("Época")
    # Set the label for the y-axis
    ax.set_ylabel("Perplexidade")
    # Set the title of the plot based on the provided condition
    ax.set_title(f"Perplexidade x Número de épocas (N = {reduced_dataset_size if reduce_dataset else 25000})")
    # Add a legend to the plot
    ax.legend()
    # Add a vertical dashed line at the index of the minimum value for the 'test' data
    if label == 'test':
        ax.axvline(x=min_value_idx, color='r', linestyle='dashed')
    # Add gridlines to the plot with a transparency level of 0.3
    ax.grid(alpha=0.3)
    # Set the x-axis ticks for every 5 units and include the index of the minimum value
    ax.set_xticks([i for i in range(0, 51, 5)] + [min_value_idx])

# Create a figure and axis for plotting
fig, ax = plt.subplots(1, 1)

# Plot the training and testing data on the same axis
plot_list_trend(ax, np.array(performance_train).transpose()[1], 'train')
plot_list_trend(ax, np.array(performance_test).transpose()[1], 'test')

# Adjust the layout of the plot for better presentation
plt.tight_layout()
# Display the plot
plt.show()

# Find the index of the maximum value in the testing data
max_value_idx = np.argmax(np.array(performance_test).transpose()[0])

# Print the best accuracy value based on the index found
print("Best accuracy:", np.array(performance_test).transpose()[0][max_value_idx])
# Out:
# Best accuracy: 85.804

# %%
# Create a figure and axis for plotting
fig, ax = plt.subplots(1, 1)

# Lists to store learning rates and corresponding accuracies
X_lr = []
Y_lr = []

# Loop through a range of learning rates
for lr in np.arange(0, 0.1, 0.001):
    # Append the learning rate to the X_lr list
    X_lr.append(lr)
    # Train the model with the current learning rate and evaluate its accuracy
    model = train(lr)
    Y_lr.append(eval(model)[0])

# Plot the learning rate versus accuracy
ax.plot(X_lr, Y_lr)

# Set the label for the x-axis
ax.set_xlabel("Learning rate")
# Set the label for the y-axis
ax.set_ylabel("Acurácia em %")

# Display the plot
plt.show()

# Find the learning rate corresponding to the maximum accuracy
max_accuracy_lr = X_lr[np.argmax(Y_lr)]

# Find the maximum accuracy achieved
max_accuracy = max(Y_lr)

# Print the learning rate corresponding to the maximum accuracy and the maximum accuracy
print(max_accuracy_lr)
print(max_accuracy)
# Out:
# Epoch [1/5],                 Loss: 0.6924,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.6924,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.6924,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.6924,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.6924,                 Elapsed Time: 0.17 sec
# test Loss: 0.0054
# test PPL: 1.0055
# test Accuracy: 49.52%
# Epoch [1/5],                 Loss: 0.6930,                 Elapsed Time: 0.20 sec
# Epoch [2/5],                 Loss: 0.6904,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.6879,                 Elapsed Time: 0.20 sec
# Epoch [4/5],                 Loss: 0.6852,                 Elapsed Time: 0.20 sec
# Epoch [5/5],                 Loss: 0.6822,                 Elapsed Time: 0.20 sec
# test Loss: 0.0054
# test PPL: 1.0054
# test Accuracy: 69.316%
# Epoch [1/5],                 Loss: 0.6915,                 Elapsed Time: 0.20 sec
# Epoch [2/5],                 Loss: 0.6859,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.6794,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.6716,                 Elapsed Time: 0.21 sec
# Epoch [5/5],                 Loss: 0.6628,                 Elapsed Time: 0.22 sec
# test Loss: 0.0052
# test PPL: 1.0052
# test Accuracy: 74.84%
# Epoch [1/5],                 Loss: 0.6904,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.6815,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.6708,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.6573,                 Elapsed Time: 0.20 sec
# Epoch [5/5],                 Loss: 0.6413,                 Elapsed Time: 0.19 sec
# test Loss: 0.0051
# test PPL: 1.0051
# test Accuracy: 75.82%
# Epoch [1/5],                 Loss: 0.6844,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.6710,                 Elapsed Time: 0.21 sec
# Epoch [3/5],                 Loss: 0.6515,                 Elapsed Time: 0.20 sec
# Epoch [4/5],                 Loss: 0.6274,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.5993,                 Elapsed Time: 0.19 sec
# test Loss: 0.0048
# test PPL: 1.0048
# test Accuracy: 77.412%
# Epoch [1/5],                 Loss: 0.6831,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.6620,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.6337,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.5993,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.5604,                 Elapsed Time: 0.21 sec
# test Loss: 0.0046
# test PPL: 1.0046
# test Accuracy: 77.496%
# Epoch [1/5],                 Loss: 0.6827,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.6608,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.6286,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.5876,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.5407,                 Elapsed Time: 0.17 sec
# test Loss: 0.0044
# test PPL: 1.0045
# test Accuracy: 78.0%
# Epoch [1/5],                 Loss: 0.6791,                 Elapsed Time: 0.22 sec
# Epoch [2/5],                 Loss: 0.6518,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.6121,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.5607,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.5044,                 Elapsed Time: 0.16 sec
# test Loss: 0.0043
# test PPL: 1.0043
# test Accuracy: 78.604%
# Epoch [1/5],                 Loss: 0.6723,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.6314,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.5748,                 Elapsed Time: 0.20 sec
# Epoch [4/5],                 Loss: 0.5099,                 Elapsed Time: 0.20 sec
# Epoch [5/5],                 Loss: 0.4482,                 Elapsed Time: 0.18 sec
# test Loss: 0.0040
# test PPL: 1.0040
# test Accuracy: 79.332%
# Epoch [1/5],                 Loss: 0.6638,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.6055,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.5327,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.4600,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.3989,                 Elapsed Time: 0.19 sec
# test Loss: 0.0037
# test PPL: 1.0037
# test Accuracy: 80.312%
# Epoch [1/5],                 Loss: 0.6643,                 Elapsed Time: 0.20 sec
# Epoch [2/5],                 Loss: 0.6095,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.5328,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.4543,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.3895,                 Elapsed Time: 0.19 sec
# test Loss: 0.0037
# test PPL: 1.0037
# test Accuracy: 80.364%
# Epoch [1/5],                 Loss: 0.6559,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.5852,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.4962,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.4166,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.3573,                 Elapsed Time: 0.18 sec
# test Loss: 0.0035
# test PPL: 1.0035
# test Accuracy: 80.964%
# Epoch [1/5],                 Loss: 0.6540,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.5737,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.4781,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.3984,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.3418,                 Elapsed Time: 0.19 sec
# test Loss: 0.0034
# test PPL: 1.0034
# test Accuracy: 81.312%
# Epoch [1/5],                 Loss: 0.6529,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.5717,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.4697,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.3853,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.3278,                 Elapsed Time: 0.16 sec
# test Loss: 0.0034
# test PPL: 1.0034
# test Accuracy: 81.648%
# Epoch [1/5],                 Loss: 0.6439,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.5433,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.4359,                 Elapsed Time: 0.16 sec
# Epoch [4/5],                 Loss: 0.3577,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.3077,                 Elapsed Time: 0.16 sec
# test Loss: 0.0033
# test PPL: 1.0033
# test Accuracy: 82.288%
# Epoch [1/5],                 Loss: 0.6371,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.5249,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.4148,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.3405,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2954,                 Elapsed Time: 0.17 sec
# test Loss: 0.0032
# test PPL: 1.0032
# test Accuracy: 82.648%
# Epoch [1/5],                 Loss: 0.6393,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.5259,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.4109,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.3354,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2909,                 Elapsed Time: 0.17 sec
# test Loss: 0.0032
# test PPL: 1.0032
# test Accuracy: 82.584%
# Epoch [1/5],                 Loss: 0.6287,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.4995,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.3843,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.3148,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2756,                 Elapsed Time: 0.17 sec
# test Loss: 0.0031
# test PPL: 1.0031
# test Accuracy: 83.052%
# Epoch [1/5],                 Loss: 0.6221,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.4847,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.3706,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.3049,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2686,                 Elapsed Time: 0.16 sec
# test Loss: 0.0031
# test PPL: 1.0031
# test Accuracy: 83.24%
# Epoch [1/5],                 Loss: 0.6240,                 Elapsed Time: 0.16 sec
# Epoch [2/5],                 Loss: 0.4815,                 Elapsed Time: 0.16 sec
# Epoch [3/5],                 Loss: 0.3654,                 Elapsed Time: 0.16 sec
# Epoch [4/5],                 Loss: 0.3009,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.2663,                 Elapsed Time: 0.16 sec
# test Loss: 0.0030
# test PPL: 1.0030
# test Accuracy: 83.416%
# Epoch [1/5],                 Loss: 0.5963,                 Elapsed Time: 0.16 sec
# Epoch [2/5],                 Loss: 0.4414,                 Elapsed Time: 0.16 sec
# Epoch [3/5],                 Loss: 0.3366,                 Elapsed Time: 0.16 sec
# Epoch [4/5],                 Loss: 0.2821,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.2534,                 Elapsed Time: 0.16 sec
# test Loss: 0.0030
# test PPL: 1.0030
# test Accuracy: 83.872%
# Epoch [1/5],                 Loss: 0.6056,                 Elapsed Time: 0.16 sec
# Epoch [2/5],                 Loss: 0.4451,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.3367,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2818,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2532,                 Elapsed Time: 0.18 sec
# test Loss: 0.0030
# test PPL: 1.0030
# test Accuracy: 83.92%
# Epoch [1/5],                 Loss: 0.5950,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.4277,                 Elapsed Time: 0.20 sec
# Epoch [3/5],                 Loss: 0.3232,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2728,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2472,                 Elapsed Time: 0.18 sec
# test Loss: 0.0029
# test PPL: 1.0029
# test Accuracy: 84.136%
# Epoch [1/5],                 Loss: 0.5952,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.4226,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.3181,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2692,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2448,                 Elapsed Time: 0.19 sec
# test Loss: 0.0029
# test PPL: 1.0029
# test Accuracy: 84.188%
# Epoch [1/5],                 Loss: 0.5811,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.4030,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.3052,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2611,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2391,                 Elapsed Time: 0.18 sec
# test Loss: 0.0029
# test PPL: 1.0029
# test Accuracy: 84.344%
# Epoch [1/5],                 Loss: 0.5694,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.3916,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.3003,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2597,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2393,                 Elapsed Time: 0.17 sec
# test Loss: 0.0029
# test PPL: 1.0029
# test Accuracy: 84.576%
# Epoch [1/5],                 Loss: 0.5781,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.3907,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2962,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2561,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2366,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0029
# test Accuracy: 84.484%
# Epoch [1/5],                 Loss: 0.5714,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.3832,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2911,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2522,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2332,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.672%
# Epoch [1/5],                 Loss: 0.5480,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.3627,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2822,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2492,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2327,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.884%
# Epoch [1/5],                 Loss: 0.5398,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.3530,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2762,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2454,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2300,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.804%
# Epoch [1/5],                 Loss: 0.5371,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.3496,                 Elapsed Time: 0.21 sec
# Epoch [3/5],                 Loss: 0.2746,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2450,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2302,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.86%
# Epoch [1/5],                 Loss: 0.5349,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.3466,                 Elapsed Time: 0.20 sec
# Epoch [3/5],                 Loss: 0.2736,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2450,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2305,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.96%
# Epoch [1/5],                 Loss: 0.5112,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.3325,                 Elapsed Time: 0.20 sec
# Epoch [3/5],                 Loss: 0.2678,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2424,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2288,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 85.128%
# Epoch [1/5],                 Loss: 0.5282,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.3377,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2696,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2436,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2301,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0028
# test Accuracy: 85.188%
# Epoch [1/5],                 Loss: 0.5211,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.3310,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2654,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2408,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2278,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.244%
# Epoch [1/5],                 Loss: 0.4973,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.3163,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2577,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2356,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2232,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.2%
# Epoch [1/5],                 Loss: 0.5021,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.3168,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2579,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2359,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2236,                 Elapsed Time: 0.19 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.26%
# Epoch [1/5],                 Loss: 0.4991,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.3147,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2579,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2369,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2250,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.2%
# Epoch [1/5],                 Loss: 0.4755,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.3015,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2493,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2298,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2184,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.3%
# Epoch [1/5],                 Loss: 0.4688,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2998,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2516,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2334,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2220,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.264%
# Epoch [1/5],                 Loss: 0.4778,                 Elapsed Time: 0.16 sec
# Epoch [2/5],                 Loss: 0.3006,                 Elapsed Time: 0.16 sec
# Epoch [3/5],                 Loss: 0.2514,                 Elapsed Time: 0.16 sec
# Epoch [4/5],                 Loss: 0.2332,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2219,                 Elapsed Time: 0.16 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.164%
# Epoch [1/5],                 Loss: 0.4697,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2971,                 Elapsed Time: 0.16 sec
# Epoch [3/5],                 Loss: 0.2505,                 Elapsed Time: 0.16 sec
# Epoch [4/5],                 Loss: 0.2333,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.2220,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.26%
# Epoch [1/5],                 Loss: 0.4561,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2897,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2474,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2319,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2213,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.256%
# Epoch [1/5],                 Loss: 0.4489,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2867,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2458,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2305,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2197,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.232%
# Epoch [1/5],                 Loss: 0.4396,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2848,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2458,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2306,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2194,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.276%
# Epoch [1/5],                 Loss: 0.4332,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2825,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2457,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2313,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2200,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.3%
# Epoch [1/5],                 Loss: 0.4390,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2818,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2452,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2312,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2204,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.32%
# Epoch [1/5],                 Loss: 0.4429,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2861,                 Elapsed Time: 0.16 sec
# Epoch [3/5],                 Loss: 0.2495,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2349,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2232,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.208%
# Epoch [1/5],                 Loss: 0.4100,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2745,                 Elapsed Time: 0.20 sec
# Epoch [3/5],                 Loss: 0.2442,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2313,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2199,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.24%
# Epoch [1/5],                 Loss: 0.4042,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2687,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2378,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2247,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2134,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.184%
# Epoch [1/5],                 Loss: 0.4068,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2727,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2434,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2303,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2186,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.196%
# Epoch [1/5],                 Loss: 0.4146,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2705,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2397,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2265,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2147,                 Elapsed Time: 0.19 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.116%
# Epoch [1/5],                 Loss: 0.4039,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2719,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2437,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2303,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2173,                 Elapsed Time: 0.19 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.048%
# Epoch [1/5],                 Loss: 0.4017,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2657,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2378,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2253,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.2131,                 Elapsed Time: 0.19 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.14%
# Epoch [1/5],                 Loss: 0.3985,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2669,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2402,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2278,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2154,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.032%
# Epoch [1/5],                 Loss: 0.3832,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2631,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2397,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2276,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2149,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 84.924%
# Epoch [1/5],                 Loss: 0.3851,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2629,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2392,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2264,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2134,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 84.964%
# Epoch [1/5],                 Loss: 0.3784,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2669,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2462,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2337,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2199,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.924%
# Epoch [1/5],                 Loss: 0.3689,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2604,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2398,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2270,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2135,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.864%
# Epoch [1/5],                 Loss: 0.3639,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2583,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2390,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2264,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2123,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.912%
# Epoch [1/5],                 Loss: 0.3590,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2584,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2404,                 Elapsed Time: 0.20 sec
# Epoch [4/5],                 Loss: 0.2279,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2143,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.74%
# Epoch [1/5],                 Loss: 0.3597,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2604,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2410,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2270,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2123,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.772%
# Epoch [1/5],                 Loss: 0.3554,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2594,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2418,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2286,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2137,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.66%
# Epoch [1/5],                 Loss: 0.3612,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2614,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2428,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2288,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2140,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.568%
# Epoch [1/5],                 Loss: 0.3497,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2588,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2421,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2289,                 Elapsed Time: 0.20 sec
# Epoch [5/5],                 Loss: 0.2140,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.62%
# Epoch [1/5],                 Loss: 0.3529,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2588,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2408,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2268,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2113,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.54%
# Epoch [1/5],                 Loss: 0.3394,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2578,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2412,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2273,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2121,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.56%
# Epoch [1/5],                 Loss: 0.3417,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2578,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2410,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2268,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2110,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.612%
# Epoch [1/5],                 Loss: 0.3405,                 Elapsed Time: 0.16 sec
# Epoch [2/5],                 Loss: 0.2600,                 Elapsed Time: 0.16 sec
# Epoch [3/5],                 Loss: 0.2435,                 Elapsed Time: 0.16 sec
# Epoch [4/5],                 Loss: 0.2290,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.2131,                 Elapsed Time: 0.16 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.508%
# Epoch [1/5],                 Loss: 0.3440,                 Elapsed Time: 0.16 sec
# Epoch [2/5],                 Loss: 0.2610,                 Elapsed Time: 0.16 sec
# Epoch [3/5],                 Loss: 0.2430,                 Elapsed Time: 0.16 sec
# Epoch [4/5],                 Loss: 0.2271,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.2102,                 Elapsed Time: 0.16 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.508%
# Epoch [1/5],                 Loss: 0.3337,                 Elapsed Time: 0.16 sec
# Epoch [2/5],                 Loss: 0.2584,                 Elapsed Time: 0.16 sec
# Epoch [3/5],                 Loss: 0.2410,                 Elapsed Time: 0.16 sec
# Epoch [4/5],                 Loss: 0.2263,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.2098,                 Elapsed Time: 0.16 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.548%
# Epoch [1/5],                 Loss: 0.3318,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2576,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2400,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2250,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2084,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.596%
# Epoch [1/5],                 Loss: 0.3357,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2602,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2422,                 Elapsed Time: 0.16 sec
# Epoch [4/5],                 Loss: 0.2255,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2093,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.472%
# Epoch [1/5],                 Loss: 0.3294,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2616,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2437,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2287,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2127,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.444%
# Epoch [1/5],                 Loss: 0.3248,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2553,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2378,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2228,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2063,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.548%
# Epoch [1/5],                 Loss: 0.3287,                 Elapsed Time: 0.16 sec
# Epoch [2/5],                 Loss: 0.2585,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2393,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2224,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2064,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.48%
# Epoch [1/5],                 Loss: 0.3253,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2592,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2417,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2251,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2104,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.492%
# Epoch [1/5],                 Loss: 0.3189,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2575,                 Elapsed Time: 0.20 sec
# Epoch [3/5],                 Loss: 0.2398,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2247,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.2096,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.492%
# Epoch [1/5],                 Loss: 0.3241,                 Elapsed Time: 0.16 sec
# Epoch [2/5],                 Loss: 0.2613,                 Elapsed Time: 0.16 sec
# Epoch [3/5],                 Loss: 0.2417,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2252,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2090,                 Elapsed Time: 0.16 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.332%
# Epoch [1/5],                 Loss: 0.3178,                 Elapsed Time: 0.21 sec
# Epoch [2/5],                 Loss: 0.2594,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2405,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2252,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2083,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.392%
# Epoch [1/5],                 Loss: 0.3154,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2588,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2411,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2266,                 Elapsed Time: 0.16 sec
# Epoch [5/5],                 Loss: 0.2112,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.36%
# Epoch [1/5],                 Loss: 0.3180,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2565,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2373,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2215,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2052,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.392%
# Epoch [1/5],                 Loss: 0.3169,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2594,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2391,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2224,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2072,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.3%
# Epoch [1/5],                 Loss: 0.3140,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2575,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2376,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2217,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2064,                 Elapsed Time: 0.17 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.26%
# Epoch [1/5],                 Loss: 0.3117,                 Elapsed Time: 0.23 sec
# Epoch [2/5],                 Loss: 0.2562,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2382,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2231,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2052,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.404%
# Epoch [1/5],                 Loss: 0.3134,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2593,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2389,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2240,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2041,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.272%
# Epoch [1/5],                 Loss: 0.3140,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2572,                 Elapsed Time: 0.20 sec
# Epoch [3/5],                 Loss: 0.2365,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2212,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.2088,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.236%
# Epoch [1/5],                 Loss: 0.3135,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2592,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2395,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2227,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2068,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.352%
# Epoch [1/5],                 Loss: 0.3109,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2581,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2399,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2253,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2085,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.292%
# Epoch [1/5],                 Loss: 0.3058,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2560,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2373,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2236,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.2103,                 Elapsed Time: 0.18 sec
# test Loss: 0.0029
# test PPL: 1.0029
# test Accuracy: 84.088%
# Epoch [1/5],                 Loss: 0.3094,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2556,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2367,                 Elapsed Time: 0.20 sec
# Epoch [4/5],                 Loss: 0.2227,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.1999,                 Elapsed Time: 0.18 sec
# test Loss: 0.0028
# test PPL: 1.0029
# test Accuracy: 84.16%
# Epoch [1/5],                 Loss: 0.3137,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2578,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2381,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2251,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2139,                 Elapsed Time: 0.18 sec
# test Loss: 0.0029
# test PPL: 1.0029
# test Accuracy: 84.004%
# Epoch [1/5],                 Loss: 0.3096,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2572,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2386,                 Elapsed Time: 0.20 sec
# Epoch [4/5],                 Loss: 0.2238,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.2019,                 Elapsed Time: 0.19 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.188%
# Epoch [1/5],                 Loss: 0.3089,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2552,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2372,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2235,                 Elapsed Time: 0.20 sec
# Epoch [5/5],                 Loss: 0.1994,                 Elapsed Time: 0.21 sec
# test Loss: 0.0028
# test PPL: 1.0028
# test Accuracy: 84.312%
# Epoch [1/5],                 Loss: 0.3080,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2558,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2370,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2233,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.1778,                 Elapsed Time: 0.19 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.208%
# Epoch [1/5],                 Loss: 0.3092,                 Elapsed Time: 0.20 sec
# Epoch [2/5],                 Loss: 0.2564,                 Elapsed Time: 0.20 sec
# Epoch [3/5],                 Loss: 0.2382,                 Elapsed Time: 0.20 sec
# Epoch [4/5],                 Loss: 0.2241,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.1790,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.056%
# Epoch [1/5],                 Loss: 0.3107,                 Elapsed Time: 0.18 sec
# Epoch [2/5],                 Loss: 0.2533,                 Elapsed Time: 0.19 sec
# Epoch [3/5],                 Loss: 0.2337,                 Elapsed Time: 0.19 sec
# Epoch [4/5],                 Loss: 0.2243,                 Elapsed Time: 0.19 sec
# Epoch [5/5],                 Loss: 0.1667,                 Elapsed Time: 0.18 sec
# test Loss: 0.0026
# test PPL: 1.0026
# test Accuracy: 85.576%
# Epoch [1/5],                 Loss: 0.3107,                 Elapsed Time: 0.19 sec
# Epoch [2/5],                 Loss: 0.2558,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2370,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2240,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.1753,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.216%
# Epoch [1/5],                 Loss: 0.3060,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2545,                 Elapsed Time: 0.18 sec
# Epoch [3/5],                 Loss: 0.2368,                 Elapsed Time: 0.18 sec
# Epoch [4/5],                 Loss: 0.2277,                 Elapsed Time: 0.18 sec
# Epoch [5/5],                 Loss: 0.1727,                 Elapsed Time: 0.18 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.224%
# Epoch [1/5],                 Loss: 0.3100,                 Elapsed Time: 0.17 sec
# Epoch [2/5],                 Loss: 0.2541,                 Elapsed Time: 0.17 sec
# Epoch [3/5],                 Loss: 0.2335,                 Elapsed Time: 0.17 sec
# Epoch [4/5],                 Loss: 0.2216,                 Elapsed Time: 0.17 sec
# Epoch [5/5],                 Loss: 0.1710,                 Elapsed Time: 0.17 sec
# test Loss: 0.0027
# test PPL: 1.0027
# test Accuracy: 85.36%
# 0.096
# 85.576
